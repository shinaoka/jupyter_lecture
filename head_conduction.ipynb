# %%
using Plots

# %%
#x = Array(0:0.1:100)
#こっちの方が良く見る
x = LinRange(0.0, 100.0, 1000)

#u = 200 .* ℯ.^( .-0.01 .*( x .- 50).^2) .+ 27
# @.マクロでbroadcast
@. u = 200 * ℯ^(-0.01*(x - 50)^2) + 27
;

# %%
plot(x, u)
